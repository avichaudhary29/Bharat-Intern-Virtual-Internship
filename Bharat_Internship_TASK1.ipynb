# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("/content/Bengaluru_House_Data.csv")
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
data=df.drop(['area_type','availability','society','balcony'],axis=1)

# %%
#Data celeaning

# %%
data.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
data1=data.dropna()

# %%
data1.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
data1['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
data1['bhk']=data1['size'].apply(lambda x:int(x.split(' ')[0]))
data1
# Out:
# <ipython-input-12-4ab88da384e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['bhk']=data1['size'].apply(lambda x:int(x.split(' ')[0]))
#                        location       size total_sqft  bath   price  bhk
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                      Kothanur      2 BHK       1200   2.0   51.00    2
# ...                         ...        ...        ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00    5
# 13316             Richards Town      4 BHK       3600   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00    4
# 13319              Doddathoguru      1 BHK        550   1.0   17.00    1
#
# [13246 rows x 6 columns]

# %%
data1.total_sqft.unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def is_float(x):
  try:
    float(x)
  except:
      return False
  return True

# %%
data1[~data1['total_sqft'].apply(is_float)]
# Out:
#                  location   size   total_sqft  bath    price  bhk
# 30              Yelahanka  4 BHK  2100 - 2850   4.0  186.000    4
# 122                Hebbal  4 BHK  3067 - 8156   4.0  477.000    4
# 137    8th Phase JP Nagar  2 BHK  1042 - 1105   2.0   54.005    2
# 165              Sarjapur  2 BHK  1145 - 1340   2.0   43.490    2
# 188              KR Puram  2 BHK  1015 - 1540   2.0   56.800    2
# ...                   ...    ...          ...   ...      ...  ...
# 12975          Whitefield  2 BHK   850 - 1060   2.0   38.190    2
# 12990      Talaghattapura  3 BHK  1804 - 2273   3.0  122.000    3
# 13059              Harlur  2 BHK  1200 - 1470   2.0   72.760    2
# 13265               Hoodi  2 BHK  1133 - 1384   2.0   59.135    2
# 13299          Whitefield  4 BHK  2830 - 2882   5.0  154.500    4
#
# [190 rows x 6 columns]

# %%
data1.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# bhk           0
# dtype: int64

# %%
def convert_sqft_to_num(x):
  tokens=x.split('-')
  if len(tokens)==2:
      return(float(tokens[0])+float(tokens[1]))/2
  try:
      return float(x)
  except:
      return None

# %%
data2=data1.copy()
data2['total_sqft']=data2['total_sqft'].apply(convert_sqft_to_num)
data2.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2

# %%
data2.location.unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
data2.location=data2.location.apply(lambda x:x.strip())

location_stats=data2.groupby('location')['location'].agg('count').sort_values(ascending=False)
location_stats
# Out:
# location
# Whitefield               535
# Sarjapur  Road           392
# Electronic City          304
# Kanakpura Road           266
# Thanisandra              236
#                         ...
# 1 Giri Nagar               1
# Kanakapura Road,           1
# Kanakapura main  Road      1
# Karnataka Shabarimala      1
# whitefiled                 1
# Name: location, Length: 1293, dtype: int64

# %%
len(location_stats[location_stats<=10])
# Out:
# 1052

# %%
locationlessthan10=location_stats[location_stats<=10]
locationlessthan10
# Out:
# location
# Basapura                 10
# 1st Block Koramangala    10
# Gunjur Palya             10
# Kalkere                  10
# Sector 1 HSR Layout      10
#                          ..
# 1 Giri Nagar              1
# Kanakapura Road,          1
# Kanakapura main  Road     1
# Karnataka Shabarimala     1
# whitefiled                1
# Name: location, Length: 1052, dtype: int64

# %%
data2.location=data2.location.apply(lambda x:'other' if x in locationlessthan10 else x)
len(data2.location.unique())
# Out:
# 242

# %%
data2[data2.total_sqft/data2.bhk<300].head()
# Out:
#                location       size  total_sqft  bath  price  bhk
# 9                 other  6 Bedroom      1020.0   6.0  370.0    6
# 45           HSR Layout  8 Bedroom       600.0   9.0  200.0    8
# 58        Murugeshpalya  6 Bedroom      1407.0   4.0  150.0    6
# 68  Devarachikkanahalli  8 Bedroom      1350.0   7.0   85.0    8
# 70                other  3 Bedroom       500.0   3.0  100.0    3

# %%
data3=data2[~(data2.total_sqft/data2.bhk<300)]
data3.shape
# Out:
# (12502, 6)

# %%
data4=data3.copy()
data4['price_per_sqft']=data4['price']*100000/data4['total_sqft']
data4.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0     3699.810606
# 1     4615.384615
# 2     4305.555556
# 3     6245.890861
# 4     4250.000000

# %%
def remove_outliers(df):
  df_out=pd.DataFrame()
  for key,subdf in df.groupby('location'):
    m=np.mean(subdf.price_per_sqft)
    st=np.std(subdf.price_per_sqft)
    reduced_df=subdf[(subdf.price_per_sqft>(m-st)) & (subdf.price_per_sqft<=(m+st))]
    df_out=pd.concat([df_out,reduced_df],ignore_index=True)
  return df_out
data5=remove_outliers(data4)
data5.shape
# Out:
# (10241, 7)

# %%
def remove_bhk_outliers(df):
  exclude_indices=np.array([])
  for location,location_df in df.groupby('location'):
    bhk_stats={}
    for bhk,bhk_df in location_df.groupby('bhk'):
      bhk_stats[bhk]={'mean':np.mean(bhk_df.price_per_sqft),
                      'std':np.std(bhk_df.price_per_sqft),
                      'count':bhk_df.shape[0]
      }
    for bhk,bhk_df in location_df.groupby('bhk'):
        stats=bhk_stats.get(bhk-1)
        if stats and stats['count']>5:
            exclude_indices=np.append(exclude_indices,bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
  return df.drop(exclude_indices,axis='index')

data6=remove_bhk_outliers(data5)
data6.shape
# Out:
# (7329, 7)

# %%
data6.bath.unique()
# Out:
# array([ 4.,  3.,  2.,  5.,  8.,  1.,  6.,  7.,  9., 12., 16., 13.])

# %%
data6[data6.bath>10]
# Out:
#             location    size  total_sqft  bath  price  bhk  price_per_sqft
# 5277  Neeladri Nagar  10 BHK      4000.0  12.0  160.0   10     4000.000000
# 8486           other  10 BHK     12000.0  12.0  525.0   10     4375.000000
# 8575           other  16 BHK     10000.0  16.0  550.0   16     5500.000000
# 9308           other  11 BHK      6000.0  12.0  150.0   11     2500.000000
# 9639           other  13 BHK      5425.0  13.0  275.0   13     5069.124424

# %%
 data6[data6.bath>data6.bhk+2]
# Out:
#            location       size  total_sqft  bath   price  bhk  price_per_sqft
# 1626  Chikkabanavar  4 Bedroom      2460.0   7.0    80.0    4     3252.032520
# 5238     Nagasandra  4 Bedroom      7000.0   8.0   450.0    4     6428.571429
# 6711    Thanisandra      3 BHK      1806.0   6.0   116.0    3     6423.034330
# 8411          other      6 BHK     11338.0   9.0  1000.0    6     8819.897689

# %%
data7=data6[data6.bath<data6.bhk+2]
data7.shape
# Out:
# (7251, 7)

# %%
data7
# Out:
#                   location       size  total_sqft  bath  price  bhk  \
# 0      1st Block Jayanagar      4 BHK      2850.0   4.0  428.0    4
# 1      1st Block Jayanagar      3 BHK      1630.0   3.0  194.0    3
# 2      1st Block Jayanagar      3 BHK      1875.0   2.0  235.0    3
# 3      1st Block Jayanagar      3 BHK      1200.0   2.0  130.0    3
# 4      1st Block Jayanagar      2 BHK      1235.0   2.0  148.0    2
# ...                    ...        ...         ...   ...    ...  ...
# 10232                other      2 BHK      1200.0   2.0   70.0    2
# 10233                other      1 BHK      1800.0   1.0  200.0    1
# 10236                other      2 BHK      1353.0   2.0  110.0    2
# 10237                other  1 Bedroom       812.0   1.0   26.0    1
# 10240                other      4 BHK      3600.0   5.0  400.0    4
#
#        price_per_sqft
# 0        15017.543860
# 1        11901.840491
# 2        12533.333333
# 3        10833.333333
# 4        11983.805668
# ...               ...
# 10232     5833.333333
# 10233    11111.111111
# 10236     8130.081301
# 10237     3201.970443
# 10240    11111.111111
#
# [7251 rows x 7 columns]

# %%
data8=data7.drop(['size','price_per_sqft'],axis=1)
data8
# Out:
#                   location  total_sqft  bath  price  bhk
# 0      1st Block Jayanagar      2850.0   4.0  428.0    4
# 1      1st Block Jayanagar      1630.0   3.0  194.0    3
# 2      1st Block Jayanagar      1875.0   2.0  235.0    3
# 3      1st Block Jayanagar      1200.0   2.0  130.0    3
# 4      1st Block Jayanagar      1235.0   2.0  148.0    2
# ...                    ...         ...   ...    ...  ...
# 10232                other      1200.0   2.0   70.0    2
# 10233                other      1800.0   1.0  200.0    1
# 10236                other      1353.0   2.0  110.0    2
# 10237                other       812.0   1.0   26.0    1
# 10240                other      3600.0   5.0  400.0    4
#
# [7251 rows x 5 columns]

# %%
data8.sort_values(by=['price'],ascending=True,inplace=True)

# %%
data8
# Out:
#               location  total_sqft  bath    price  bhk
# 1568        Chandapura       410.0   1.0    10.00    1
# 563           Attibele       410.0   1.0    10.00    1
# 9237             other       470.0   2.0    10.00    1
# 546           Attibele       400.0   1.0    10.00    1
# 541           Attibele       395.0   1.0    10.25    1
# ...                ...         ...   ...      ...  ...
# 10018            other      6729.0   4.0   900.00    3
# 8704             other      7500.0   4.0   900.00    4
# 1701   Cunningham Road      5270.0   4.0  1250.00    4
# 8413             other     30000.0   4.0  2100.00    4
# 4903      Malleshwaram     12000.0   7.0  2200.00    7
#
# [7251 rows x 5 columns]

# %%
data8.corr()
# Out:
# <ipython-input-37-d9e72a48703a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data8.corr()
#             total_sqft      bath     price       bhk
# total_sqft    1.000000  0.693915  0.840997  0.670212
# bath          0.693915  1.000000  0.601308  0.892910
# price         0.840997  0.601308  1.000000  0.570145
# bhk           0.670212  0.892910  0.570145  1.000000

# %%
data8=pd.get_dummies(data8,drop_first=True)
data8
# Out:
#        total_sqft  bath    price  bhk  location_1st Phase JP Nagar  \
# 1568        410.0   1.0    10.00    1                            0
# 563         410.0   1.0    10.00    1                            0
# 9237        470.0   2.0    10.00    1                            0
# 546         400.0   1.0    10.00    1                            0
# 541         395.0   1.0    10.25    1                            0
# ...           ...   ...      ...  ...                          ...
# 10018      6729.0   4.0   900.00    3                            0
# 8704       7500.0   4.0   900.00    4                            0
# 1701       5270.0   4.0  1250.00    4                            0
# 8413      30000.0   4.0  2100.00    4                            0
# 4903      12000.0   7.0  2200.00    7                            0
#
#        location_2nd Phase Judicial Layout  location_2nd Stage Nagarbhavi  \
# 1568                                    0                              0
# 563                                     0                              0
# 9237                                    0                              0
# 546                                     0                              0
# 541                                     0                              0
# ...                                   ...                            ...
# 10018                                   0                              0
# 8704                                    0                              0
# 1701                                    0                              0
# 8413                                    0                              0
# 4903                                    0                              0
#
#        location_5th Block Hbr Layout  location_5th Phase JP Nagar  \
# 1568                               0                            0
# 563                                0                            0
# 9237                               0                            0
# 546                                0                            0
# 541                                0                            0
# ...                              ...                          ...
# 10018                              0                            0
# 8704                               0                            0
# 1701                               0                            0
# 8413                               0                            0
# 4903                               0                            0
#
#        location_6th Phase JP Nagar  ...  location_Vishveshwarya Layout  \
# 1568                             0  ...                              0
# 563                              0  ...                              0
# 9237                             0  ...                              0
# 546                              0  ...                              0
# 541                              0  ...                              0
# ...                            ...  ...                            ...
# 10018                            0  ...                              0
# 8704                             0  ...                              0
# 1701                             0  ...                              0
# 8413                             0  ...                              0
# 4903                             0  ...                              0
#
#        location_Vishwapriya Layout  location_Vittasandra  location_Whitefield  \
# 1568                             0                     0                    0
# 563                              0                     0                    0
# 9237                             0                     0                    0
# 546                              0                     0                    0
# 541                              0                     0                    0
# ...                            ...                   ...                  ...
# 10018                            0                     0                    0
# 8704                             0                     0                    0
# 1701                             0                     0                    0
# 8413                             0                     0                    0
# 4903                             0                     0                    0
#
#        location_Yelachenahalli  location_Yelahanka  \
# 1568                         0                   0
# 563                          0                   0
# 9237                         0                   0
# 546                          0                   0
# 541                          0                   0
# ...                        ...                 ...
# 10018                        0                   0
# 8704                         0                   0
# 1701                         0                   0
# 8413                         0                   0
# 4903                         0                   0
#
#        location_Yelahanka New Town  location_Yelenahalli  \
# 1568                             0                     0
# 563                              0                     0
# 9237                             0                     0
# 546                              0                     0
# 541                              0                     0
# ...                            ...                   ...
# 10018                            0                     0
# 8704                             0                     0
# 1701                             0                     0
# 8413                             0                     0
# 4903                             0                     0
#
#        location_Yeshwanthpur  location_other
# 1568                       0               0
# 563                        0               0
# 9237                       0               1
# 546                        0               0
# 541                        0               0
# ...                      ...             ...
# 10018                      0               1
# 8704                       0               1
# 1701                       0               0
# 8413                       0               1
# 4903                       0               0
#
# [7251 rows x 245 columns]

# %%
#Linear Regression
x=data8.drop('price',axis=1)
y=data8['price']
print(x.shape,y.shape)
# Out:
# (7251, 244) (7251,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=51)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (5075, 244) (2176, 244) (5075,) (2176,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x_train)
x_train=sc.transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
reg
# Out:
# LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# 96.27840985221677

# %%
pred=reg.predict(x_test)

# %%
reg.score(x_test,y_test)
# Out:
# 0.8698280658498498

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,pred)
rmse=np.sqrt(mse)
print("Mean square error",mse)
print("Root mean square error",rmse)
# Out:
# Mean square error 930.835332148526
# Root mean square error 30.509594100029027

# %%
print(r2_score(y_test,pred))
# Out:
# 0.8698280658498498
